# %% [markdown]
# ## Assignment 1 (10 points): Data Visualization with ggplot

# %%
library("tidyverse")
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
# ✔ ggplot2 3.2.1     ✔ purrr   0.3.3
# ✔ tibble  2.1.3     ✔ dplyr   0.8.3
# ✔ tidyr   1.0.0     ✔ stringr 1.4.0
# ✔ readr   1.3.1     ✔ forcats 0.4.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %% [markdown]
# ### Q1 (3 points): Reproduce the following figure using the mpg dataset.

# %%
library(tidyverse)
ggplot(mpg,mapping = aes (x=displ, y=hwy, color = drv, shape = drv, linetype = drv))+
geom_smooth()+
geom_point()
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %%
# Out:
# `geom_smooth()` using method = 'loess' and formula 'y ~ x'
# plot without title

# %% [markdown]
# ### Q2 (3 points): Reproduce the following figure using the diamonds dataset.

# %%
library(tidyverse)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
# ✔ ggplot2 3.2.1     ✔ purrr   0.3.3
# ✔ tibble  2.1.3     ✔ dplyr   0.8.3
# ✔ tidyr   1.0.0     ✔ stringr 1.4.0
# ✔ readr   1.3.1     ✔ forcats 0.4.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
ggplot(diamonds)+
geom_bar(aes(x=cut,y=stat(count/1000),fill=color)) +
coord_flip()+
facet_wrap(~clarity)
# Out:
# plot without title

# %%
# Out:
# plot without title

# %%
library(tidyverse)

# %%
ggplot(diamonds)+
geom_boxplot(aes(x=cut,y=log10(price),color=color))+
coord_polar()
# Out:
# plot without title

# %% [markdown]
# ### Q3 (4 points): Reproduce the following figure using the diamonds dataset.

# %%
# Out:
# plot without title
